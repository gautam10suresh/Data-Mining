# %%
import pandas as pd
import numpy as np
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Plot the dendrogram
from scipy.cluster.hierarchy import dendrogram,linkage

# %%
hdi1=pd.read_csv("GDL-Human-Development-(2019)-data.csv")
hdi2=pd.read_csv("GDL-Human-Development-(2020)-data.csv")
hdi3=pd.read_csv("GDL-Human-Development-(2021)-data.csv")

h1=hdi1['Subnational HDI']
h2=hdi2['Subnational HDI']
h3=hdi3['Subnational HDI']

# %%
data1=pd.read_csv("India_SDG_Index_Rank_Data_2019.csv")
data2=pd.read_csv("India_SDG_Index_Rank_Data_2020.csv")
data3=pd.read_csv("India_SDG_Index_Rank_Data_2021.csv")

# %%
con_1=pd.concat([hdi1['Subnational HDI'],hdi2['Subnational HDI'],hdi3['Subnational HDI']],axis=1)
con_1
# Out:
#     Subnational HDI  Subnational HDI  Subnational HDI
# 0             0.645            0.642            0.633
# 1             0.642            0.639            0.630
# 2             0.677            0.674            0.665
# 3             0.609            0.606            0.597
# 4             0.581            0.578            0.571
# 5             0.617            0.614            0.605
# 6             0.765            0.761            0.751
# 7             0.650            0.646            0.638
# 8             0.704            0.701            0.691
# 9             0.717            0.713            0.703
# 10            0.600            0.597            0.589
# 11            0.679            0.676            0.667
# 12            0.766            0.762            0.752
# 13            0.607            0.604            0.596
# 14            0.701            0.698            0.688
# 15            0.691            0.687            0.678
# 16            0.654            0.651            0.643
# 17            0.701            0.697            0.688
# 18            0.683            0.679            0.670
# 19            0.608            0.605            0.597
# 20            0.707            0.703            0.694
# 21            0.650            0.647            0.638
# 22            0.715            0.711            0.702
# 23            0.699            0.695            0.686
# 24            0.658            0.656            0.647
# 25            0.640            0.637            0.629
# 26            0.603            0.600            0.592
# 27            0.684            0.681            0.672
# 28            0.636            0.633            0.624

# %%
con_2=pd.concat([data1,data2,data3],axis=1)
con_2
# Out:
#     2018  2019               AREA  Goal 10  2019  2020               AREA  \
# 0     71    64              India       64    64    67              India
# 1     75    68     Andhra Pradesh       68    68    74     Andhra Pradesh
# 2     47    38  Arunachal Pradesh       38    38    69  Arunachal Pradesh
# 3     75    67              Assam       67    67    65              Assam
# 4     82    74              Bihar       74    74    48              Bihar
# 5     73    60       Chhattisgarh       60    60    72       Chhattisgarh
# 6     50    19                Goa       19    19    75                Goa
# 7     79    59            Gujarat       59    59    64            Gujarat
# 8     55    54            Haryana       54    54    68            Haryana
# 9     98    78   Himachal Pradesh       78    78    78   Himachal Pradesh
# 10    72    64          Jharkhand       64    64    65          Jharkhand
# 11    68    70          Karnataka       70    70    67          Karnataka
# 12    72    75             Kerala       75    75    69             Kerala
# 13    75    68     Madhya Pradesh       68    68    51     Madhya Pradesh
# 14    76    70        Maharashtra       70    70    71        Maharashtra
# 15    98    81            Manipur       81    81    70            Manipur
# 16   100    76          Meghalaya       76    76    88          Meghalaya
# 17   100    66            Mizoram       66    66    64            Mizoram
# 18    80    61           Nagaland       61    61    46           Nagaland
# 19    78    69             Odisha       69    69    66             Odisha
# 20    62    50             Punjab       50    50    68             Punjab
# 21    79    70          Rajasthan       70    70    45          Rajasthan
# 22    67    64             Sikkim       64    64    61             Sikkim
# 23    85    65         Tamil Nadu       65    65    74         Tamil Nadu
# 24   100    94          Telangana       94    94    67          Telangana
# 25    89    45            Tripura       45    45    85            Tripura
# 26    38    46      Uttar Pradesh       46    46    41      Uttar Pradesh
# 27    62    59        Uttarakhand       59    59    77        Uttarakhand
# 28    76    73        West Bengal       73    73    71        West Bengal
#
#     Goal 10  2020  2021               AREA  Goal 10
# 0        67    64    67              India       67
# 1        74    68    74     Andhra Pradesh       74
# 2        69    38    69  Arunachal Pradesh       69
# 3        65    67    65              Assam       65
# 4        48    74    48              Bihar       48
# 5        72    60    72       Chhattisgarh       72
# 6        75    19    75                Goa       75
# 7        64    59    64            Gujarat       64
# 8        68    54    68            Haryana       68
# 9        78    78    78   Himachal Pradesh       78
# 10       65    64    65          Jharkhand       65
# 11       67    70    67          Karnataka       67
# 12       69    75    69             Kerala       69
# 13       51    68    51     Madhya Pradesh       51
# 14       71    70    71        Maharashtra       71
# 15       70    81    70            Manipur       70
# 16       88    76    88          Meghalaya       88
# 17       64    66    64            Mizoram       64
# 18       46    61    46           Nagaland       46
# 19       66    69    66             Odisha       66
# 20       68    50    68             Punjab       68
# 21       45    70    45          Rajasthan       45
# 22       61    64    61             Sikkim       61
# 23       74    65    74         Tamil Nadu       74
# 24       67    94    67          Telangana       67
# 25       85    45    85            Tripura       85
# 26       41    46    41      Uttar Pradesh       41
# 27       77    59    77        Uttarakhand       77
# 28       71    73    71        West Bengal       71

# %%
con_2.drop(['2018','2019','2020','2021','AREA'],axis=1,inplace=True)
con_2
# Out:
#     Goal 10  Goal 10  Goal 10
# 0        64       67       67
# 1        68       74       74
# 2        38       69       69
# 3        67       65       65
# 4        74       48       48
# 5        60       72       72
# 6        19       75       75
# 7        59       64       64
# 8        54       68       68
# 9        78       78       78
# 10       64       65       65
# 11       70       67       67
# 12       75       69       69
# 13       68       51       51
# 14       70       71       71
# 15       81       70       70
# 16       76       88       88
# 17       66       64       64
# 18       61       46       46
# 19       69       66       66
# 20       50       68       68
# 21       70       45       45
# 22       64       61       61
# 23       65       74       74
# 24       94       67       67
# 25       45       85       85
# 26       46       41       41
# 27       59       77       77
# 28       73       71       71

# %%
data=pd.concat([con_1,con_2],axis=1)
data
# Out:
#     Subnational HDI  Subnational HDI  Subnational HDI  Goal 10  Goal 10  \
# 0             0.645            0.642            0.633       64       67
# 1             0.642            0.639            0.630       68       74
# 2             0.677            0.674            0.665       38       69
# 3             0.609            0.606            0.597       67       65
# 4             0.581            0.578            0.571       74       48
# 5             0.617            0.614            0.605       60       72
# 6             0.765            0.761            0.751       19       75
# 7             0.650            0.646            0.638       59       64
# 8             0.704            0.701            0.691       54       68
# 9             0.717            0.713            0.703       78       78
# 10            0.600            0.597            0.589       64       65
# 11            0.679            0.676            0.667       70       67
# 12            0.766            0.762            0.752       75       69
# 13            0.607            0.604            0.596       68       51
# 14            0.701            0.698            0.688       70       71
# 15            0.691            0.687            0.678       81       70
# 16            0.654            0.651            0.643       76       88
# 17            0.701            0.697            0.688       66       64
# 18            0.683            0.679            0.670       61       46
# 19            0.608            0.605            0.597       69       66
# 20            0.707            0.703            0.694       50       68
# 21            0.650            0.647            0.638       70       45
# 22            0.715            0.711            0.702       64       61
# 23            0.699            0.695            0.686       65       74
# 24            0.658            0.656            0.647       94       67
# 25            0.640            0.637            0.629       45       85
# 26            0.603            0.600            0.592       46       41
# 27            0.684            0.681            0.672       59       77
# 28            0.636            0.633            0.624       73       71
#
#     Goal 10
# 0        67
# 1        74
# 2        69
# 3        65
# 4        48
# 5        72
# 6        75
# 7        64
# 8        68
# 9        78
# 10       65
# 11       67
# 12       69
# 13       51
# 14       71
# 15       70
# 16       88
# 17       64
# 18       46
# 19       66
# 20       68
# 21       45
# 22       61
# 23       74
# 24       67
# 25       85
# 26       41
# 27       77
# 28       71

# %%
# Remove rows where the Location Description is missing
data.dropna(subset=['Goal 10'], inplace=True)
data
# Out:
#     Subnational HDI  Subnational HDI  Subnational HDI  Goal 10  Goal 10  \
# 0             0.645            0.642            0.633       64       67
# 1             0.642            0.639            0.630       68       74
# 2             0.677            0.674            0.665       38       69
# 3             0.609            0.606            0.597       67       65
# 4             0.581            0.578            0.571       74       48
# 5             0.617            0.614            0.605       60       72
# 6             0.765            0.761            0.751       19       75
# 7             0.650            0.646            0.638       59       64
# 8             0.704            0.701            0.691       54       68
# 9             0.717            0.713            0.703       78       78
# 10            0.600            0.597            0.589       64       65
# 11            0.679            0.676            0.667       70       67
# 12            0.766            0.762            0.752       75       69
# 13            0.607            0.604            0.596       68       51
# 14            0.701            0.698            0.688       70       71
# 15            0.691            0.687            0.678       81       70
# 16            0.654            0.651            0.643       76       88
# 17            0.701            0.697            0.688       66       64
# 18            0.683            0.679            0.670       61       46
# 19            0.608            0.605            0.597       69       66
# 20            0.707            0.703            0.694       50       68
# 21            0.650            0.647            0.638       70       45
# 22            0.715            0.711            0.702       64       61
# 23            0.699            0.695            0.686       65       74
# 24            0.658            0.656            0.647       94       67
# 25            0.640            0.637            0.629       45       85
# 26            0.603            0.600            0.592       46       41
# 27            0.684            0.681            0.672       59       77
# 28            0.636            0.633            0.624       73       71
#
#     Goal 10
# 0        67
# 1        74
# 2        69
# 3        65
# 4        48
# 5        72
# 6        75
# 7        64
# 8        68
# 9        78
# 10       65
# 11       67
# 12       69
# 13       51
# 14       71
# 15       70
# 16       88
# 17       64
# 18       46
# 19       66
# 20       68
# 21       45
# 22       61
# 23       74
# 24       67
# 25       85
# 26       41
# 27       77
# 28       71

# %%
# Standardize the data
scaler = StandardScaler()
data_std = scaler.fit_transform(data)
data_std
# Out:
# array([[-0.42756504, -0.42392281, -0.4322092 ,  0.02201272,  0.0533979 ,
#          0.0533979 ],
#        [-0.49126051, -0.48806418, -0.49715255,  0.30573224,  0.69103167,
#          0.69103167],
#        [ 0.25185338,  0.26025174,  0.26051988, -1.82216413,  0.23557898,
#          0.23557898],
#        [-1.19191075, -1.19361918, -1.21152941,  0.23480236, -0.12878317,
#         -0.12878317],
#        [-1.78640186, -1.79227192, -1.77437179,  0.73131151, -1.67732232,
#         -1.67732232],
#        [-1.02205615, -1.02257555, -1.03834714, -0.26170679,  0.50885059,
#          0.50885059],
#        [ 2.12025401,  2.12035131,  2.12222928, -3.16983183,  0.7821222 ,
#          0.7821222 ],
#        [-0.32140591, -0.33840099, -0.32397028, -0.33263667, -0.21987371,
#         -0.21987371],
#        [ 0.82511266,  0.83752402,  0.82336226, -0.68728607,  0.14448844,
#          0.14448844],
#        [ 1.10112639,  1.09408948,  1.08313566,  1.01503103,  1.05539382,
#          1.05539382],
#        [-1.38299718, -1.38604328, -1.38471168,  0.02201272, -0.12878317,
#         -0.12878317],
#        [ 0.29431703,  0.30301265,  0.30381545,  0.44759199,  0.0533979 ,
#          0.0533979 ],
#        [ 2.14148584,  2.14173177,  2.14387706,  0.80224139,  0.23557898,
#          0.23557898],
#        [-1.2343744 , -1.23638009, -1.2331772 ,  0.30573224, -1.4040507 ,
#         -1.4040507 ],
#        [ 0.76141719,  0.77338266,  0.75841891,  0.44759199,  0.41776005,
#          0.41776005],
#        [ 0.54909893,  0.53819766,  0.54194107,  1.22782066,  0.32666952,
#          0.32666952],
#        [-0.23647861, -0.23149872, -0.21573136,  0.87317127,  1.9662992 ,
#          1.9662992 ],
#        [ 0.76141719,  0.7520022 ,  0.75841891,  0.16387248, -0.21987371,
#         -0.21987371],
#        [ 0.37924433,  0.36715402,  0.3687588 , -0.19077692, -1.85950339,
#         -1.85950339],
#        [-1.21314258, -1.21499964, -1.21152941,  0.37666212, -0.03769264,
#         -0.03769264],
#        [ 0.88880814,  0.88028493,  0.88830561, -0.97100558,  0.14448844,
#          0.14448844],
#        [-0.32140591, -0.31702054, -0.32397028,  0.44759199, -1.95059393,
#         -1.95059393],
#        [ 1.05866274,  1.05132857,  1.06148788,  0.02201272, -0.49314533,
#         -0.49314533],
#        [ 0.71895354,  0.70924129,  0.71512334,  0.0929426 ,  0.69103167,
#          0.69103167],
#        [-0.15155131, -0.12459644, -0.12914023,  2.14990909,  0.0533979 ,
#          0.0533979 ],
#        [-0.53372416, -0.53082509, -0.51880033, -1.32565498,  1.69302758,
#          1.69302758],
#        [-1.3193017 , -1.32190191, -1.31976833, -1.2547251 , -2.31495608,
#         -2.31495608],
#        [ 0.40047616,  0.40991493,  0.41205437, -0.33263667,  0.96430328,
#          0.96430328],
#        [-0.61865146, -0.6163469 , -0.62703925,  0.66038163,  0.41776005,
#          0.41776005]])

# %%
# Perform single linkage clustering with 3 clusters
cluster = AgglomerativeClustering(n_clusters=3, linkage='average')
cluster_labels=cluster.fit_predict(data_std)
cluster.fit(data_std)
# Out:
# AgglomerativeClustering(linkage='average', n_clusters=3)

# %%
# Add the cluster labels to the original dataset
data["cluster"] = cluster.labels_

# %%
# Print the number of samples in each cluster
print(data["cluster"].value_counts())
# Out:
# 0    23
# 2     5
# 1     1
# Name: cluster, dtype: int64

# %%
# No.of total clusters

plt.figure(figsize=(12, 7))
plt.title("SDG 10 Dataset Dendrogram (Average Linkage)")
dend = dendrogram(
    linkage(data_std, method='average'),
    truncate_mode='lastp',  # Show only the last p merged clusters
    p=3,  
    leaf_rotation=90.,
    leaf_font_size=12.,
    show_contracted=True,  # Collapse all intermediate nodes
)
plt.show()

# %%
plt.figure(figsize=(12, 7))
plt.title("SDG 10 Dataset Dendrogram (Average Linkage)")
dend = dendrogram(
    linkage(data_std, method='average'),
    truncate_mode='level',  # Show only the last p merged clusters
    p=3,  
    leaf_rotation=90.,
    leaf_font_size=12.,
    show_contracted=True,  # Collapse all intermediate nodes
)
plt.show()

# %%
#Accuracy using sihouette_score
from sklearn.metrics import silhouette_score

# %%
silhouette = silhouette_score(data_std, cluster_labels)
print(f"Silhouette score: {silhouette}")
# Out:
# Silhouette score: 0.32491305502024
